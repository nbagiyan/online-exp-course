# %% [markdown]
# # HW-2
#
# GLHF
#
# Ссылка на данные https://disk.yandex.ru/d/QpIzgTbjAPjaWA
#
# Итак! У нас есть сервис для продажи некоторых товаров (например, мыла).
# Мы выкатываем новые фичи и проводим тесты, а затем сохраняем логи каждого теста в следующем формате:
#
# - `user_id` - уникальный id посетителя сайта
# - `dt` - дата события
# - `event` - название события
# - `group` - группа, в которую попал пользователь (распределение может происходить на разных этапах воронки для разных тестов - например, при первом посещении или при первом добавлении в корзину)
# - `visit_id` - уникальный id визита
# - `cart_id` - уникальный id корзины
# - `amount` - текущая сумма корзины
# - `num_items` - текущее количество товаров в корзине

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Для этого задания вам даны две очень похожие группы (файл `aa_test_logs.pkl`).
#
# Поработаем с метрикой **average revenue per paying user**.
#
# - К какому виду метрик (с точки зрения изучаемых на курсе категорий) относится эта метрика? Какие тесты для проверки гипотез по ней могут использоваться? Какие для них должны выполняться предпосылки? Ответ дайте письменно.
#
# - Посчитайте метрику и проверьте, что группы реально похожи (на уровне ошибки первого рода не более 5%). Прокомментируйте используемые методы и результаты.
#
# - Найдите, на каком уровне искусственно добавленного эффекта ARPPU в группах станет статистически значимо различима. Ошибку первого рода считайте заданной и равной 0.05, ошибку 2-го рода равной 0.2. Прокомментируйте используемые методы и результаты.

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Поработаем с теми же группами, но другой метрикой - **средний чек**. Представим, что мы планируем эксперимент с влиянием на эту метрику и выбираем наиболее подходящий тест.
#
# - Аналогично предыдущему заданию, опишите, какие тесты для проверки гипотез по ней больше всего подходят? Почему? Какие для них должны выполняться предпосылки?
#
# - Посчитайте метрику **средний чек** по группам на данных `aa_test_logs.pkl` и сравните мощность, как минимум, двух тестов их тех, что вы описали. Какой метод получился наиболее мощным? Как вы думаете, почему?

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Мы сделали рекомендательную систему, которая после добавления товара в корзину предлагает добавить похожие или комплементарные. По результатам нашей аналитики, это должно было повысить выручку на наших Power Users, которых мы определяем как топ-5% по ARPPU. Логи проведенного эксперимента сохранены в файле `ab_test_logs.pkl`.
#
# - Проверьте гипотезу о том, что это изменение значимо повлияло на 95%-й процентиль ARPPU
#
# - Можем ли мы на основании такого эксперимента делать выводы о наличии (или отсутствии) эффекта от изменения на выручку наших Power Users? Обоснуйте. (если нет, приведите дизайн корректного эксперимента)

# %% [markdown]
# ### Задание 4

# %% [markdown]
# Ненадолого отдохнем от магазина мыла. В приложенном файле `sleep.csv` приведены данные с фитнес-браслета по времени засыпания одного и того же человека в разные дни.
#
# - По этой выборке найдите такое время суток (с точностью до минуты), после которого с вероятностью 0.9 этот человек уже спит.
#
# - Постройте доверительный интервал для оценки этого времени.
#
# - А теперь постройте доверительный интервал для оценки этого времени, но уже другим способом. Сравните с предыдущим. На сколько отличается ширина получившегося ДИ от ДИ из предыдущего пункта? Почему имеет место такое отличие? Дайте развернутый ответ.
